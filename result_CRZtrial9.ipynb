# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit 
 
def f(x, a, b): 
    return a + b * np.log(x) 

result=[]
bottom=[]
result.append(131.15211394712523)
result.append(118.28199462775184)
result.append(120.26703681740078)
result.append(111.80780548074794)
result.append(98.4362001006781)
result.append(117.39148847445362)
result.append(183.72373489545177)
result.append(170.90467473569774)
result.append(159.9767699018937)
result.append(169.1209148779257)
result.append(158.1409737422319)
result.append(192.1059260443355)
result.append(221.64200092072136)
result.append(239.72751687927232)
result.append(233.9256289996018)
result.append(261.5253627496167)
result.append(283.2128698814779)
result.append(245.0733575767781)
result.append(307.15224802071947)
result.append(335.03354151881496)
result.append(373.2821547175184)
result.append(439.35305320170806)
result.append(544.0671154285994)
result.append(398.87204372669083)
result.append(1139.2983382496068)

# for i in range(100):
#     bottom.append(i)
x = np.linspace(0, 25, 25)
res2=np.polyfit(x, result, 2)
# result[99]=32
# a_pred, b_pred = curve_fit(f, x, result)[0] 
# y_pred = f(x, a_pred, b_pred) 
y2 = np.poly1d(res2)(x) #2次
fig, ax = plt.subplots() 
ax.plot(x, result, "blue") 
ax.set_xlabel("epoch") 
# ax.plot(x, y2, "r--") 
# ax.legend() 
ax.grid() 
# plt.show()
# plt.plot(bottom,result)

# %%
x = np.linspace(0, 100, 100)
for i in range(len(result),100):
    result.append(120-i)
res2=np.polyfit(x, result, 2)
# result[99]=32
# a_pred, b_pred = curve_fit(f, x, result)[0] 
# y_pred = f(x, a_pred, b_pred) 
y2 = np.poly1d(res2)(x) #2次
for i in range(66,100):
    y2[i]=y2[66]
fig, ax = plt.subplots() 
ax.plot(x, result, "gray") 
ax.plot(x, y2, "r--") 
# ax.legend() 
ax.grid()
