# %%
import matplotlib.pyplot as plt
import numpy as np
result=[]
bottom=[]
result.append(2.00000000e+00) 
result.append(2.76167820e-01) 
result.append(1.27596560e+00) 
result.append(2.63668076e-01)
result.append(1.11641313e+00) 
result.append(4.43700972e-01) 
result.append(1.00154474e+00) 
result.append(2.92559454e+00)
result.append(9.57013636e-01) 
result.append(2.58695953e-01) 
result.append(2.59436935e-01) 
result.append(2.58127472e-01)
result.append(1.85645429e+00) 
result.append(2.58346419e-01) 
result.append(4.55518689e-01) 
result.append(1.03731574e+00)
result.append(2.53795342e-01) 
result.append(1.11869838e+00) 
result.append(9.49183980e-01) 
result.append(2.50309602e-01)
result.append(1.26966918e+00) 
result.append(3.96301804e-01) 
result.append(2.53058774e-01) 
result.append(7.87277739e-04)
result.append(1.29754109e+00) 
result.append(9.62138017e-01) 
result.append(2.34843553e+00) 
result.append(1.93864887e-01)
result.append(9.56241239e-01) 
result.append(2.69397260e-01) 
result.append(1.28326105e+00) 
result.append(5.48226347e-01)
result.append(4.08384288e+00) 
result.append(4.89118413e+00) 
result.append(4.18254216e+00) 
result.append(1.01478448e+00)
result.append(9.93812200e-01) 
result.append(1.07808195e+00) 
result.append(1.19575139e+00) 
result.append(9.95181467e-01)
result.append(9.92416615e-01) 
result.append(1.20537106e+00) 
result.append(2.52824114e+00) 
result.append(2.88190372e-01)
result.append(5.05359516e-01) 
result.append(1.13833914e+00) 
result.append(9.62015859e-01) 
result.append(4.54049591e-02)
result.append(4.09140778e+00) 
result.append(1.42786127e+00) 
result.append(9.83390223e-01) 
result.append(3.00524360e+00)
result.append(5.07370062e-01) 
result.append(3.80085850e+00) 
result.append(3.14084471e+00) 
result.append(5.07370062e-01)
result.append(1.36393536e+00) 
result.append(3.54595711e-01) 
result.append(2.37980250e-01) 
result.append(3.18420195e-01)
result.append(4.75225941e-01) 
result.append(9.50553286e-01) 
result.append(4.95755012e+00) 
result.append(1.40977884e+00)
result.append(6.78162796e-01) 
result.append(2.12765945e+00) 
result.append(5.14146907e-01) 
result.append(6.55015357e-01)
result.append(5.13864556e-01) 
result.append(2.60493410e-01) 
result.append(5.13369744e-01) 
result.append(3.90863727e+00)
result.append(4.49719715e-02) 
result.append(4.13855882e-01) 
result.append(3.39688578e-01) 
result.append(2.82711479e-01)
result.append(5.95891125e-01) 
result.append(6.71843889e-01) 
result.append(1.44284192e+00) 
result.append(1.29521034e+00)
result.append(2.22701761e+00) 
result.append(2.44016562e-01) 
result.append(3.47460608e-01) 
result.append(7.01197790e-01)
result.append(9.12700804e-01) 
result.append(8.73809275e-01) 
result.append(1.41697626e+00) 
result.append(1.32545407e+00)
result.append(1.21622369e+00) 
result.append(7.82462993e-01) 
result.append(1.25124488e+00) 
result.append(9.39153248e-02)
result.append(5.14104650e-01) 
result.append(3.71681352e-01) 
result.append(1.43129553e+00) 
result.append(1.12925405e+00)
result.append(1.17666725e+00) 
result.append(1.79725010e-01) 
result.append(3.59304708e-01) 
result.append(3.43581530e-01)
for i in range(100):
    bottom.append(i)
    result[i]=result[i]*100
plt.plot(bottom,result)
