.68247309,0.5346715775471698,0.22144090269999997,0.38233488250000003,0.38233488250000003,0.5246677388571428,0.59227593,0.38233488250000003,0.4349540398412698,0.38233488250000003,0.2576507672,0.68247309,0.5659280930487804,0.59227593,0.59227593,0.5353347662337662,0.6540790914705882,-0.23480339,0.34011760073170727,0.5735701063636364,0.59227593,0.5461818970588236,-0.23480339,0.38233488250000003,0.38233488250000003,0.59227593,0.57145255575,0.15996715718446602,-0.06938752600000002,0.5076471633870968,0.5191286857377049,0.37672721666666664,0.38233488250000003,0.38233488250000003,0.38233488250000003,-0.04683081727272726,0.4893939,0.5268055472727272,-0.043851878805970176,0.38233488250000003,0.04373402923076923,0.38233488250000003,0.38233488250000003,-0.23480339,0.4893939,0.59227593,0.15904390523809522,0.23570313412371136,-0.23480339,0.5931739646249999,0.499017794,0.4893939,0.4893939]
result_zero = sorted(result_zero) #ソート
result_one = sorted(result_one) #ソート
y = [0]*100 #y=0

#数直線
fig,ax=plt.subplots(figsize=(10,10)) #画像サイズ
fig.set_figheight(1) #高さ調整
ax.tick_params(labelbottom=True, bottom=False) #x軸設定
ax.tick_params(labelleft=False, left=False) #y軸設定

xmin, xmax= -0.3,0.7 #数直線の最小値・最大値
plt.tight_layout() #グラフの自動調整
# plt.scatter(result_zero,y,c='r') #散布図
plt.scatter(result_one,y,c='b') #散布図
# plt.scatter(result_one,y,c='b') #散布図
plt.hlines(y=0,xmin=xmin,xmax=xmax) #横軸
# plt.vlines(x=[i for i in range(xmin,xmax+1,1)],ymin=-0.04,ymax=0.04) #目盛り線（大）
plt.vlines(x=0,ymin=-0.04,ymax=0.04) #目盛り線（大）
plt.vlines(x=[i/10 for i in range(-1*10,1*10+1,1)],ymin=-0.02,ymax=0.02) #目盛り線（小）
line_width=0.1#目盛り数値の刻み幅
plt.xticks(np.arange(xmin,xmax+line_width,line_width)) #目盛り数値
pylab.box(False) #枠を消す

# %%
plt.scatter(result_one,y,c='b') #散布図
plt.hlines(y=0,xmin=xmin,xmax=xmax) #横軸
# plt.vlines(x=[i for i in range(xmin,xmax+1,1)],ymin=-0.04,ymax=0.04) #目盛り線（大）
plt.vlines(x=0,ymin=-0.04,ymax=0.04) #目盛り線（大）
plt.vlines(x=[i/10 for i in range(-1*10,1*10+1,1)],ymin=-0.02,ymax=0.02) #目盛り線（小）
line_width=0.1#目盛り数値の刻み幅
plt.xticks(np.arange(xmin,xmax+line_width,line_width)) #目盛り数値
pylab.box(False) #枠を消す
