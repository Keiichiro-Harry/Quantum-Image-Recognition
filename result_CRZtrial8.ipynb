# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit 
 
def f(x, a, b): 
    return a + b * np.log(x) 

result=[]
bottom=[]
# result.append(101.15902740847511)#0
# result.append(150)#0
result=[1.30073829e+002, 1.17555028e+002, 1.22771913e+002, 1.46826485e+002,
 1.67841098e+002, 1.87046436e+002, 1.53426466e+002, 1.91384099e+002,
 2.28937847e+002, 2.14757838e+002, 2.06663073e+002, 2.39757440e+002,
 2.34246421e+002, 3.10487966e+002, 4.40525679e+002, 1.10288979e+003,
 4.86856280e+003] #2.72842532e+005, 6.58386143e+008, 4.18563919e+015]
#  1.25049433e+029, 1.38374192e+056, 1.60534723e+110, 1.97370514e+218]
# for i in range(100):
#     bottom.append(i)
x = np.linspace(0, 17, 17)
res2=np.polyfit(x, result, 2)
# result[99]=32
# a_pred, b_pred = curve_fit(f, x, result)[0] 
# y_pred = f(x, a_pred, b_pred) 
y2 = np.poly1d(res2)(x) #2次
fig, ax = plt.subplots() 
ax.plot(x, result, "blue") 
ax.set_xlabel("epoch") 
# ax.plot(x, y2, "r--") 
# ax.legend() 
ax.grid() 
# plt.show()
# plt.plot(bottom,result)

# %%
x = np.linspace(0, 100, 100)
for i in range(len(result),100):
    result.append(120-i)
res2=np.polyfit(x, result, 2)
# result[99]=32
# a_pred, b_pred = curve_fit(f, x, result)[0] 
# y_pred = f(x, a_pred, b_pred) 
y2 = np.poly1d(res2)(x) #2次
for i in range(66,100):
    y2[i]=y2[66]
fig, ax = plt.subplots() 
ax.plot(x, result, "gray") 
ax.plot(x, y2, "r--") 
# ax.legend() 
ax.grid()
